# %% [markdown]
# # Introduction to matplotlib

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# %matplotlib inline

# %%
plt.plot()
# Out:
# []

# %%
plt.plot();

# %%
plt.plot()
plt.show()

# %%
plt.plot([1, 2, 3, 4]);

# %%
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]

plt.plot(x, y);

# %%
# 1st method
fig = plt.figure() # creates a figure
ax = fig.add_subplot() # add some axes
plt.show()

# %%
# 2nd method
fig = plt.figure() #creates a figure
ax = fig.add_axes([1, 1, 1, 1])
ax.plot(x, y)

# %%
# 3rd method (recommended)

fig, ax = plt.subplots()
ax.plot(x, [100, 230, 350, 400]); # add some data

type(fig), type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._subplots.AxesSubplot)

# %% [markdown]
# ### Matplotlib example workflow

# %%
# 0. import matplotlib and get it redy for plotting in jupyter
import matplotlib.pyplot as plt
# %matplotlib inline

# 1. Prepare data
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]

# 2. setup plot
fig, ax = plt.subplots(figsize=(10, 10)) #width and heigth 

# 3. plot data
ax.plot(x, y)

# 4. customize plot
ax.set(title= 'Simple Plot',
       xlabel= 'x-axis',
       ylabel= 'y-labal')

# 5. save and show (you save the whole figure)
fig.savefig("images\sample-plot.png")

# %%
fig, ax = plt.subplots(figsize=(5, 5))

data = np.random.randint(10, size=(2, 8))
x = data[0]
y = data[1]

ax.plot(x, y)

ax.set(title= 'random graph',
       xlabel= 'Random x',
       ylabel= 'Random y')

plt.show()

# %% [markdown]
# ## Making figures with NumPy
#
# We want:
# - Line Plot
# - Scatter Plot
# - Bar Plot
# - Histogram
# - Sub Plot

# %%
import numpy as np

# %%
# create some data
x =  np.linspace(0, 10, 100) #linspace creates equal number of spaces between two numbers

# %%
#plot the data
fig, ax = plt.subplots(figsize= (5, 5))
ax.plot (x, x**2);

# %%
# Use the same data to make a scatter
fig, ax = plt.subplots()
ax.scatter(x, np.exp(x));

# %%
# another scatter plot
fig, ax = plt.subplots()
ax.scatter(x, np.sin(x));

# %%
# making a plot from dictionary
nut_butter_prices= {'Almond butter': 10,
                    'Peanut butter': 8,
                    'Cashew butter': 12}
fig, ax = plt.subplots()
ax.bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax.set(title= "Dan's Nut Butter Store",
       ylabel= "Prices($)")
# Out:
# [Text(0.5, 1.0, "Dan's Nut Butter Store"), Text(0, 0.5, 'Prices($)')]

# %%
fig, ax = plt.subplots()
ax.barh(list(nut_butter_prices.keys()), list(nut_butter_prices.values()));
ax.set(title= "Dan's Nut Butter Store",
       xlabel= 'Prices($)')
# Out:
# [Text(0.5, 1.0, "Dan's Nut Butter Store"), Text(0.5, 0, 'Prices($)')]

# %%
# make some data for histograms and plot it
x = np.random.randn(1000)
fig, ax = plt.subplots()
ax.hist(x);

# %% [markdown]
# ### Two Options for subplots

# %%
# subplot Option 1
fig, ((ax1, ax2), (ax3, ax4))= plt.subplots(nrows=2,
                                            ncols=2,
                                            figsize= (10, 5))

#plot to different axis
ax1.plot(x, x/2);

y = np.linspace(0, 360, 45)
ax2.scatter(y, np.cos(y));

ax3.bar(nut_butter_prices.keys(), nut_butter_prices.values());

ax4.hist(np.random.randn(1000));

# %%
# subplots option 2
fig, ax = plt.subplots(nrows=2,
                       ncols=2,
                       figsize= (10, 5))

#plot to each different axis
ax[0, 0].plot(x, x/2);
ax[0, 1].scatter(np.random.random(10), np.random.random(10));
ax[1, 0].bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax[1, 1].hist(np.random.randn(1000));

# %% [markdown]
# ## Plotting from Pandas Dataframes

# %%
import pandas as pd

# %%
# make a dataframe
car_sales = pd.read_csv("..\car-sales.csv")

car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
ts = pd.Series(np.random.randn(1000),
               index= pd.date_range("1/1/2020", periods=1000))
ts = ts.cumsum()
ts.plot();

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', "")
car_sales
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   """Entry point for launching an IPython kernel.
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
# removing last 2 zeros
car_sales.Price = car_sales.Price.str[:-2]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["Sales_Date"] = pd.date_range("1/1/2020", periods= len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Sales_Date
# 0  Toyota  White         150043      4   4000 2020-01-01
# 1   Honda    Red          87899      4   5000 2020-01-02
# 2  Toyota   Blue          32549      3   7000 2020-01-03
# 3     BMW  Black          11179      5  22000 2020-01-04
# 4  Nissan  White         213095      4   3500 2020-01-05
# 5  Toyota  Green          99213      4   4500 2020-01-06
# 6   Honda   Blue          45698      4   7500 2020-01-07
# 7   Honda   Blue          54738      4   7000 2020-01-08
# 8  Toyota  White          60000      4   6250 2020-01-09
# 9  Nissan  White          31600      4   9700 2020-01-10

# %%
car_sales["Total_sales"] = car_sales.Price.astype(int).cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Sales_Date  Total_sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000 2020-01-08        60500
# 8  Toyota  White          60000      4   6250 2020-01-09        66750
# 9  Nissan  White          31600      4   9700 2020-01-10        76450

# %%
# plotting the total sales
car_sales.plot(x="Sales_Date", y= "Total_sales");

# %%
# reassign price column to int
car_sales.Price = car_sales.Price.astype(int)

# Plot scatter
car_sales.plot(x= "Odometer (KM)", y= "Price", kind= "scatter")
# Out:
# <AxesSubplot:xlabel='Odometer (KM)', ylabel='Price'>

# %%
type(car_sales.Price[0])
# Out:
# numpy.int32

# %%
# How about a bar graph?

x = np.random.rand(10, 4)
x

#turn it into a dataframe
df = pd.DataFrame(x, columns= ['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0  0.798447  0.885516  0.582878  0.645771
# 1  0.387959  0.420063  0.049162  0.016572
# 2  0.609511  0.314559  0.802627  0.096047
# 3  0.414989  0.894859  0.564053  0.085897
# 4  0.106601  0.738726  0.460326  0.373302
# 5  0.503941  0.935745  0.754027  0.308738
# 6  0.737126  0.787691  0.119975  0.468221
# 7  0.304627  0.334759  0.337731  0.098620
# 8  0.102810  0.774910  0.704073  0.472792
# 9  0.260713  0.823063  0.266494  0.157736

# %%
df.plot.bar();

# %%
df.plot(kind= 'bar')
# Out:
# <AxesSubplot:>

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Sales_Date  Total_sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000 2020-01-08        60500
# 8  Toyota  White          60000      4   6250 2020-01-09        66750
# 9  Nissan  White          31600      4   9700 2020-01-10        76450

# %%
car_sales.plot(x= "Make", y= "Odometer (KM)", kind= "bar")
# Out:
# <AxesSubplot:xlabel='Make'>

# %%
# how about histograms

car_sales["Odometer (KM)"].plot.hist();

# %%
 car_sales["Odometer (KM)"].plot(kind= "hist");

# %%
car_sales["Odometer (KM)"].plot.hist(bins= 10);

# %%
# trying on another dataset

heart_disease = pd.read_csv("../heart-disease.csv")
heart_disease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %%
# create a histogram of age

heart_disease.age.plot.hist(bins= 50);

# %%
heart_disease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %%
heart_disease.plot.hist(figsize=(10, 50), subplots=True);

# %% [markdown]
# ### Which one should you use? (pyplot vs Matplotlib OO method)
#
# * when plotting something quickly, okay to use the pyplot
#
# * when plotting something more advanced, use the OO method

# %%
heart_disease.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
# 7   44    1   1       120   263    0        1      173      0      0.0      2
# 8   52    1   2       172   199    1        1      162      0      0.5      2
# 9   57    1   2       150   168    0        1      174      0      1.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1
# 7   0     3       1
# 8   0     3       1
# 9   0     2       1

# %%
over_50 = heart_disease[heart_disease.age > 50]
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
over_50.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 208 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       208 non-null    int64
#  1   sex       208 non-null    int64
#  2   cp        208 non-null    int64
#  3   trestbps  208 non-null    int64
#  4   chol      208 non-null    int64
#  5   fbs       208 non-null    int64
#  6   restecg   208 non-null    int64
#  7   thalach   208 non-null    int64
#  8   exang     208 non-null    int64
#  9   oldpeak   208 non-null    float64
#  10  slope     208 non-null    int64
#  11  ca        208 non-null    int64
#  12  thal      208 non-null    int64
#  13  target    208 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 24.4 KB

# %%
# pyplot method
over_50.plot(kind= 'scatter',
             x= 'age',
             y= 'chol',
             c= 'target',);

# %%
## OO Method mixed with pyplot

fig, ax = plt.subplots(figsize= (10, 6))
over_50.plot(kind= 'scatter',
             x= 'age',
             y= 'chol',
             c= 'target',
             ax=ax);

#ax.set_xlim([45, 100])

# %%
## OO Method from scratch
fig, ax = plt.subplots(figsize= (10, 6))

# plot the data
scatter = ax.scatter(x= over_50.age,
                     y= over_50.chol,
                     c= over_50.target);

# customizing the plot
ax.set(title= "Heart diseases and Cholesterol Levels",
       xlabel= "Age",
       ylabel= 'Cholesterol');

# add a legend
ax.legend(*scatter.legend_elements(), title= "Target")

# add a horizontal line
ax.axhline(over_50.chol.mean(),
           linestyle= '--')

# %%
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
# subplot of chol, age, thalach
fig, (ax0, ax1) = plt.subplots(nrows= 2,
                               ncols= 1,
                               figsize= (10, 10),
                               sharex= True); #makes subplots to share the x-axis

# add data to ax0
scatter = ax0.scatter(x= over_50.age,
                      y= over_50.chol,
                      c= over_50.target);

# customize ax0
ax0.set(title= "Heart disease and cholesterol levels",
        #xlabel= "Age",
        ylabel= "Cholesterol");

# add a legend
ax0.legend(*scatter.legend_elements(), title= "Target");

# add a meanline
ax0.axhline(over_50.chol.mean(),
            linestyle= '--');

# adding data to ax1
scatter1 = ax1.scatter(x= over_50.age,
                       y= over_50.thalach,
                       c= over_50.target);

# customizing ax1
ax1.set(title= "Heart Diseases and Thalach Levels",
        xlabel= "Age",
        ylabel= "Thalach");

# adding a legend
ax1.legend(*scatter1.legend_elements(), title= "Target");

# adding a mean line
ax1.axhline(over_50.thalach.mean(), linestyle= "--");

# add a title to the figure
fig.suptitle("Heart Disease Analysis", fontsize= 16, fontweight= 'bold');

# %%
# see the different styles available
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
car_sales.head
# Out:
# <bound method NDFrame.head of      Make Colour  Odometer (KM)  Doors  Price Sales_Date  Total_sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000 2020-01-08        60500
# 8  Toyota  White          60000      4   6250 2020-01-09        66750
# 9  Nissan  White          31600      4   9700 2020-01-10        76450>

# %%
car_sales.Price.plot()
# Out:
# <AxesSubplot:>

# %%
plt.style.use('seaborn-whitegrid');

# %%
car_sales.Price.plot()
# Out:
# <AxesSubplot:>

# %%
plt.style.use('seaborn')

# %%
car_sales.Price.plot()
# Out:
# <AxesSubplot:>

# %%
# create some dummy data
x = np.random.randn(10, 4)
x
# Out:
# array([[ 0.88772129, -2.07316451,  1.11082394, -0.40898313],
#        [-0.11075758, -1.31231798,  1.47562579, -0.56497923],
#        [ 0.04516388, -1.54718217, -1.70067822,  1.34304931],
#        [ 0.41342837,  0.6312865 , -0.7862234 ,  0.67846727],
#        [-0.34581136, -0.24061858, -1.04996084, -1.18023414],
#        [-0.33907356, -0.74515798,  0.83559067, -0.23985144],
#        [-0.52661655, -0.51782176, -2.33918481,  0.25527182],
#        [-1.11059421,  0.02129869,  0.06416837,  0.0222475 ],
#        [ 0.38076996, -0.44047047,  1.12645455,  0.46283162],
#        [-1.04660839,  0.62666899, -0.47208771,  0.16824058]])

# %%
df = pd.DataFrame(x, columns=['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0  0.887721 -2.073165  1.110824 -0.408983
# 1 -0.110758 -1.312318  1.475626 -0.564979
# 2  0.045164 -1.547182 -1.700678  1.343049
# 3  0.413428  0.631287 -0.786223  0.678467
# 4 -0.345811 -0.240619 -1.049961 -1.180234
# 5 -0.339074 -0.745158  0.835591 -0.239851
# 6 -0.526617 -0.517822 -2.339185  0.255272
# 7 -1.110594  0.021299  0.064168  0.022248
# 8  0.380770 -0.440470  1.126455  0.462832
# 9 -1.046608  0.626669 -0.472088  0.168241

# %%
ax = df.plot(kind= 'bar')
type(ax)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
# customizing our plot with the set() method
ax = df.plot(kind= 'bar')

#add some labels and a title
ax.set(title= 'Random numbers according to columns',
       xlabel= 'Rows',
       ylabel= 'Random number')

# make the legend visible
ax.legend().set_visible(True) # false also applicable

# %%
plt.style.use('seaborn-whitegrid')

## OO Method from scratch
fig, ax = plt.subplots(figsize= (10, 6))

# plot the data
scatter = ax.scatter(x= over_50.age,
                     y= over_50.chol,
                     c= over_50.target,
                     cmap= 'winter'); # this changes the color scheme

# customizing the plot
ax.set(title= "Heart diseases and Cholesterol Levels",
       xlabel= "Age",
       ylabel= 'Cholesterol');

# add a legend
ax.legend(*scatter.legend_elements(), title= "Target")

# add a horizontal line
ax.axhline(over_50.chol.mean(),
           linestyle= '--')

# %%
# customizing the x and y axis limitation


# subplot of chol, age, thalach
fig, (ax0, ax1) = plt.subplots(nrows= 2,
                               ncols= 1,
                               figsize= (10, 10),
                               sharex= True); #makes subplots to share the x-axis

# add data to ax0
scatter = ax0.scatter(x= over_50.age,
                      y= over_50.chol,
                      c= over_50.target,
                      cmap= 'winter');

# customize ax0
ax0.set(title= "Heart disease and cholesterol levels",
        #xlabel= "Age",
        ylabel= "Cholesterol");

# change x axis limits
ax0.set_xlim([50, 80])

# add a legend
ax0.legend(*scatter.legend_elements(), title= "Target");

# add a meanline
ax0.axhline(over_50.chol.mean(),
            linestyle= '--');

# adding data to ax1
scatter1 = ax1.scatter(x= over_50.age,
                       y= over_50.thalach,
                       c= over_50.target,
                       cmap= 'winter');

# customizing ax1
ax1.set(title= "Heart Diseases and Thalach Levels",
        xlabel= "Age",
        ylabel= "Thalach");

# change y axis lim
ax1.set_ylim([60, 200])

# adding a legend
ax1.legend(*scatter1.legend_elements(), title= "Target");

# adding a mean line
ax1.axhline(over_50.thalach.mean(), linestyle= "--");

# add a title to the figure
fig.suptitle("Heart Disease Analysis", fontsize= 16, fontweight= 'bold');
